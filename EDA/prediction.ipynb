# %%
import pandas as pd
import pickle

# %%
model = pickle.load(open("../code/model_file/best_model.pkl","rb"))
scaler = pickle.load(open("../code/model_file/scaling.pkl","rb"))

# %%
model.predict_proba([[0,79.33,1,78.33,0,1,77.48,1,1,86.5,0,66.28,200000.0]])
# Out:
# array([[0.55696203, 0.44303797]])

# %%
model.predict([[0,73.0,1,79.0,1,0,72.0,0,0,91.34,0,61.29,231000.0]])
# Out:
# array([0], dtype=int64)

# %%
df = pd.read_csv("../code/clean_data/clean_train.csv", )

# %%
df.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       0  67.00      0  91.00      0      0     58.00         1       0
# 1       0  79.33      1  78.33      0      1     77.48         1       1
# 2       0  65.00      1  68.00      1      2     64.00         0       0
# 3       0  56.00      1  52.00      1      1     52.00         1       0
# 4       0  85.80      1  73.60      1      0     73.30         0       0
#
#    etest_p  specialisation  mba_p  status         salary
# 0     55.0               1  58.80       1  270000.000000
# 1     86.5               0  66.28       1  200000.000000
# 2     75.0               0  57.80       1  250000.000000
# 3     66.0               1  59.43       0  288655.405405
# 4     96.8               0  55.50       1  425000.000000

# %%
X = df.drop(columns=['status'])

# %%
X
# Out:
#      gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0         0  67.00      0  91.00      0      0     58.00         1       0
# 1         0  79.33      1  78.33      0      1     77.48         1       1
# 2         0  65.00      1  68.00      1      2     64.00         0       0
# 3         0  56.00      1  52.00      1      1     52.00         1       0
# 4         0  85.80      1  73.60      1      0     73.30         0       0
# ..      ...    ...    ...    ...    ...    ...       ...       ...     ...
# 210       0  80.60      0  82.00      0      0     77.60         0       0
# 211       0  58.00      0  60.00      0      1     72.00         1       0
# 212       0  67.00      0  67.00      0      0     73.00         0       1
# 213       1  74.00      0  66.00      0      0     58.00         0       0
# 214       0  62.00      1  58.00      0      1     53.00         0       0
#
#      etest_p  specialisation  mba_p         salary
# 0       55.0               1  58.80  270000.000000
# 1       86.5               0  66.28  200000.000000
# 2       75.0               0  57.80  250000.000000
# 3       66.0               1  59.43  288655.405405
# 4       96.8               0  55.50  425000.000000
# ..       ...             ...    ...            ...
# 210     91.0               0  74.49  400000.000000
# 211     74.0               0  53.62  275000.000000
# 212     59.0               0  69.72  295000.000000
# 213     70.0               1  60.23  204000.000000
# 214     89.0               1  60.22  288655.405405
#
# [215 rows x 13 columns]

# %%
y = df['status']

# %%
scaled_X = scaler.transform(X)

# %%
df_new = pd.DataFrame(scaled_X, columns=X.columns)

# %%
model.predict([scaled_X[0]])
# Out:
# array([1], dtype=int64)

# %%
model.score(scaled_X, y)
# Out:
# 0.4511627906976744

# %%
from sklearn.metrics import precision_score, recall_score

# %%
X.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_
# 214 -0.728431 -0.485347  1.027032 -0.704586 -0.805203  0.737154 -1.767863
#
#      degree_t    workex   etest_p  specialisation     mba_p    salary  status
# 0    1.005858 -0.717741 -1.284444        1.083473 -0.592736 -0.254907       1
# 1    1.005858  1.393261  1.180504       -0.922958  0.689164 -1.096897       1
# 2   -0.689409 -0.717741  0.280602       -0.922958 -0.764113 -0.495476       1
# 3    1.005858 -0.717741 -0.423668        1.083473 -0.484769 -0.030512       0
# 4   -0.689409 -0.717741  1.986502       -0.922958 -1.158281  1.609500       1
# ..        ...       ...       ...             ...       ...       ...     ...
# 210 -0.689409 -0.717741  1.532639       -0.922958  2.096171  1.308789       1
# 211  1.005858 -0.717741  0.202350       -0.922958 -1.480470 -0.194765       1
# 212 -0.689409  1.393261 -0.971434       -0.922958  1.278702  0.045804       1
# 213 -0.689409 -0.717741 -0.110659        1.083473 -0.347667 -1.048783       1
# 214 -0.689409 -0.717741  1.376135        1.083473 -0.349381 -0.030512       0
#
# [215 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_new.drop(columns=['status'], axis=1)
y = df_new['status']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.shape
# Out:
# (161, 13)

# %%
X_test.shape
# Out:
# (54, 13)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=50)

# %%
model.score(X_train,y_train)
# Out:
# 0.7453416149068323

# %%
model.score(X_test,y_test)
# Out:
# 0.7777777777777778

# %%
y_pred = model.predict(X_test)

# %%
df_new
# Out:
#        gender     ssc_p     ssc_b     hsc_p     hsc_b     hsc_s  degree_p  \
# 0   -0.728431 -0.036777 -0.973680  2.418803 -0.805203 -0.913191 -1.110792
# 1   -0.728431  1.069398  1.027032  1.219611 -0.805203  0.737154  1.449157
# 2   -0.728431 -0.216205  1.027032  0.241895  1.241923  2.387500 -0.322307
# 3   -0.728431 -1.023632  1.027032 -1.272475  1.241923  0.737154 -1.899277
# 4   -0.728431  1.649848  1.027032  0.771925  1.241923 -0.913191  0.899846
# ..        ...       ...       ...       ...       ...       ...       ...
# 210 -0.728431  1.183335 -0.973680  1.566969 -0.805203 -0.913191  1.464927
# 211 -0.728431 -0.844204 -0.973680 -0.515290 -0.805203  0.737154  0.729007
# 212 -0.728431 -0.036777 -0.973680  0.147247 -0.805203 -0.913191  0.860422
# 213  1.372813  0.591222 -0.973680  0.052599 -0.805203 -0.913191 -1.110792
# 214 -0.728431 -0.485347  1.027032 -0.704586 -0.805203  0.737154 -1.767863
#
#      degree_t    workex   etest_p  specialisation     mba_p    salary  status
# 0    1.005858 -0.717741 -1.284444        1.083473 -0.592736 -0.254907       1
# 1    1.005858  1.393261  1.180504       -0.922958  0.689164 -1.096897       1
# 2   -0.689409 -0.717741  0.280602       -0.922958 -0.764113 -0.495476       1
# 3    1.005858 -0.717741 -0.423668        1.083473 -0.484769 -0.030512       0
# 4   -0.689409 -0.717741  1.986502       -0.922958 -1.158281  1.609500       1
# ..        ...       ...       ...             ...       ...       ...     ...
# 210 -0.689409 -0.717741  1.532639       -0.922958  2.096171  1.308789       1
# 211  1.005858 -0.717741  0.202350       -0.922958 -1.480470 -0.194765       1
# 212 -0.689409  1.393261 -0.971434       -0.922958  1.278702  0.045804       1
# 213 -0.689409 -0.717741 -0.110659        1.083473 -0.347667 -1.048783       1
# 214 -0.689409 -0.717741  1.376135        1.083473 -0.349381 -0.030512       0
#
# [215 rows x 14 columns]

# %%
column_names = scaler.feature_names_in_
column_names
# Out:
# array(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'salary'], dtype=object)

# %%
import numpy as np
df['new'] = df_new.drop(columns=['status'], axis=1)
df_scaled = scaler.transform(df_new)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3799, in DataFrame._set_item_mgr(self, key, value)
#    3798 try:
# -> 3799     loc = self._info_axis.get_loc(key)
#    3800 except KeyError:
#    3801     # This item wasn't present, just insert at end
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df['new'] = df_new.drop(columns=['status'], axis=1)
#       3 df_scaled = scaler.transform(df_new)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3645, in DataFrame.__setitem__(self, key, value)
#    3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
# -> 3645     self._set_item_frame_value(key, value)
#    3646 elif (
#    3647     is_list_like(value)
#    3648     and not self.columns.is_unique
#    3649     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3650 ):
#    3651     # Column to set is duplicated
#    3652     self._setitem_array([key], value)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3788, in DataFrame._set_item_frame_value(self, key, value)
#    3786 # now align rows
#    3787 arraylike = _reindex_for_setitem(value, self.index)
# -> 3788 self._set_item_mgr(key, arraylike)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3802, in DataFrame._set_item_mgr(self, key, value)
#    3799     loc = self._info_axis.get_loc(key)
#    3800 except KeyError:
#    3801     # This item wasn't present, just insert at end
# -> 3802     self._mgr.insert(len(self._info_axis), key, value)
#    3803 else:
#    3804     self._iset_item_mgr(loc, value)
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py:1235, in BlockManager.insert(self, loc, item, value)
#    1233     value = value.T
#    1234     if len(value) > 1:
# -> 1235         raise ValueError(
#    1236             f"Expected a 1D array, got an array with shape {value.T.shape}"
#    1237         )
#    1238 else:
#    1239     value = ensure_block_shape(value, ndim=self.ndim)
#
# ValueError: Expected a 1D array, got an array with shape (215, 13)

# %%
np.array(df_new)[0]
# Out:
# array([-0.72843136, -0.03677679, -0.97367959,  2.41880277, -0.80520286,
#        -0.91319133, -1.11079196,  1.00585843, -0.71774056, -1.2844437 ,
#         1.08347268, -0.5927363 , -0.25490688,  1.        ])
